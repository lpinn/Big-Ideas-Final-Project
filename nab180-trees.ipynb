# %% [markdown]
# # Best Neighborhood: TREES

# %% [markdown]
# Nathan Barta's work. Data set (trees):https://data.wprdc.org/datastore/dump/1515a93c-73e3-4425-9b35-1cd11b2196da

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import trees dataset (into pandas)

# %%
treesData = pd.read_csv("https://data.wprdc.org/datastore/dump/1515a93c-73e3-4425-9b35-1cd11b2196da", index_col="id", low_memory=False)
dictionaryMetric = {}
print(treesData.head(1))
# Out:
#           address_number         street common_name scientific_name  height  \
# id
# 754166088           7428  MONTICELLO ST       Stump           Stump     0.0
#
#            width  growth_space_length  growth_space_width growth_space_type  \
# id
# 754166088    0.0                 10.0                 2.0       Well or Pit
#
#            diameter_base_height  ...    neighborhood council_district  ward  \
# id                               ...
# 754166088                  16.0  ...  Homewood North              9.0  13.0
#
#                   tract  public_works_division  pli_division  police_zone  \
# id
# 754166088  4.200313e+10                    2.0          13.0          5.0
#
#            fire_zone   latitude  longitude
# id
# 754166088       3-17  40.458169 -79.889724
#
# [1 rows x 57 columns]

# %% [markdown]
# ## Create a tree metric. 10 trees = 1 point.

# %%
def treeMetricAdd():
    for i in range(0, len(treesData) - 1):
        if (treesData["neighborhood"].iloc[i] in dictionaryMetric):
            dictionaryMetric[treesData["neighborhood"].iloc[i]] += 0.1
        else:
            dictionaryMetric[treesData["neighborhood"].iloc[i]] = 0.1
    for k in dictionaryMetric:
        dictionaryMetric[k] = round(dictionaryMetric[k])
            
treeMetricAdd()
dictionaryMetric = {k: dictionaryMetric[k] for k in dictionaryMetric if type(k) is str}
print(dictionaryMetric)
# Out:
# {'Homewood North': 80, 'Oakwood': 18, 'South Side Flats': 338, 'East Allegheny': 78, 'Highland Park': 588, 'Stanton Heights': 140, 'Sheraden': 78, 'Chartiers City': 8, 'Elliott': 34, 'Morningside': 92, 'Bloomfield': 288, 'Friendship': 72, 'Garfield': 126, 'Polish Hill': 54, 'Lower Lawrenceville': 102, 'Central Northside': 134, 'East Liberty': 274, 'Central Lawrenceville': 142, 'Shadyside': 312, 'Allegheny Center': 174, 'Homewood South': 92, 'Point Breeze North': 114, 'East Hills': 96, 'Homewood West': 18, 'Greenfield': 149, 'Hazelwood': 130, 'Squirrel Hill South': 1014, 'Marshall-Shadeland': 98, 'Brighton Heights': 182, 'North Shore': 92, 'Overbrook': 56, 'Knoxville': 86, 'Brookline': 170, 'South Side Slopes': 46, 'Arlington': 22, 'Arlington Heights': 0, 'Carrick': 154, 'Bedford Dwellings': 40, 'Central Business District': 200, 'Bluff': 44, 'West Oakland': 16, 'South Oakland': 46, 'Squirrel Hill North': 416, 'Point Breeze': 264, 'Lincoln-Lemington-Belmar': 105, 'Bon Air': 18, 'Mount 
# ...

# %% [markdown]
# ## Graph for analysis

# %%
data = pd.DataFrame(dictionaryMetric.items(), columns=["Neighborhood", "Value"]).sort_values(by=["Value"])
plt.figure(figsize=(20, 25))
plt.barh(data["Neighborhood"], data["Value"])
# Out:
# <BarContainer object of 90 artists>

# %% [markdown]
# ## Conclusion

# %% [markdown]
# I chose my metric to be 1 point for every 10 trees. The reason I did this was to make the amount of trees scale reasonably to my team mates' metrics. I believe 20 trees is about equivilant to a small inner-city park in terms of enjoyment. The data set I used was the "trees" data set by WPRDC, which includes the location of every tree in inner pittsburgh, along with which neighborhood it resides in. After analyzing the data, I found that Squirrel Hill South contained the greatest amount of trees, accumilating 507 points. This makes sense because Squirrel Hill South contains Schenley and Frick park. Highland park has the second greatest amount of trees, accumilating 294 points. This also makes sense, considering that half of Highland park is a park.
